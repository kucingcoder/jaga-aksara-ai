# %% [markdown]
# # IMAGES PROCESSING

# %% [markdown]
# The purpose of image processing is to equalize the image size so that it can be used as a dataset and change the image to black and white so that it can be processed more quickly in model training

# %% [markdown]
# ## Install Library

# %% [markdown]
# install the libraries required by the code

# %%
# %pip install scikit-image numpy matplotlib
# Out:
# Requirement already satisfied: scikit-image in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (0.24.0)
# Requirement already satisfied: numpy in c:\users\hanif\appdata\roaming\python\python311\site-packages (1.26.0)
# Requirement already satisfied: matplotlib in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (3.9.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (3.3)
# Requirement already satisfied: pillow>=9.1 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (10.3.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (2024.9.20)
# Requirement already satisfied: packaging>=21 in c:\users\hanif\appdata\roaming\python\python311\site-packages (from scikit-image) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hanif\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hanif\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Library

# %% [markdown]
# import libraries that will be used in the code

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, transform, util
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu

# %% [markdown]
# ## Load Raw Images

# %% [markdown]
# Load all the images that will be processed

# %%
category = []
images = []

for root, dirs, files in os.walk('../Images/Raw'):
    for file in files:
        if file.endswith(('.png', '.jpg', '.jpeg')):
            category.append(os.path.basename(root))

            file_path = os.path.join(root, file)
            img = io.imread(file_path)[:,:,:3]
            images.append(img)

# %% [markdown]
# Check the amount of data that has been loaded

# %%
print(f'Total Class : {len(set(category))}')
print(f'Total Image : {len(images)}')
# Out:
# Total Class : 3
# Total Image : 30

# %% [markdown]
# check 9 randomly selected image data

# %%
sample_images = random.sample(images, 9)

fig, axes = plt.subplots(3, 3, figsize=(9, 9))
axes = axes.flatten()

for ax, img in zip(axes, sample_images):
    ax.imshow(img)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Change Image Color

# %% [markdown]
# change the image color to black and white so that the size is small & easy to process in model training

# %%
black_white_images = []

for img in images:
    gray_img = rgb2gray(img)
    threshold = threshold_otsu(gray_img)
    white_black_img = gray_img > threshold
    final = util.invert(white_black_img)
    black_white_images.append(final)

# %% [markdown]
# check 9 randomly selected image data

# %%
sample_images = random.sample(black_white_images, 9)

fig, axes = plt.subplots(3, 3, figsize=(9, 9))
axes = axes.flatten()

for ax, img in zip(axes, sample_images):
    ax.imshow(img, cmap='gray')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Resize Images

# %% [markdown]
# change the size of the image data to make it the same

# %%
resized_images = []
standard_size = (25, 25)

for img in black_white_images:
    resize_img = transform.resize(img, standard_size)
    resized_images.append(resize_img)

# %% [markdown]
# check 9 randomly selected image data

# %%
sample_images = random.sample(resized_images, 9)

fig, axes = plt.subplots(3, 3, figsize=(9, 9))
axes = axes.flatten()

for ax, img in zip(axes, sample_images):
    ax.imshow(img, cmap='gray')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save Preprocessed Image

# %% [markdown]
# save the image processing results in the Processed folder

# %%
for x in range(len(resized_images)):
    path = f'../Images/Processed/{category[x]}/{x+1}.png'
    img = resized_images[x].astype(np.uint8) * 255
    io.imsave(path, img)
